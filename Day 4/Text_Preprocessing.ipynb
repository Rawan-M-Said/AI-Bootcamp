# %% [markdown]
# # Importing necessary libraries

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
import string
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Rawan
# [nltk_data]     Mohamed\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\Rawan
# [nltk_data]     Mohamed\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Rawan Mohamed\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# # Sample text

# %%
text = "Natural Language Processing (NLP) helps computers to understand human language."

# %% [markdown]
# # Lowercasing

# %%
text = text.lower()
print("Lowercased Text:", text)
# Out:
# Lowercased Text: natural language processing (nlp) helps computers to understand human language.

# %% [markdown]
# # Removing punctuation

# %%
text = text.translate(str.maketrans('', '', string.punctuation))
print("Text without Punctuation:", text)
# Out:
# Text without Punctuation: natural language processing nlp helps computers to understand human language

# %% [markdown]
# # Tokenization

# %%
tokens = word_tokenize(text)
print("Tokens:", tokens)
# Out:
# Tokens: ['natural', 'language', 'processing', 'nlp', 'helps', 'computers', 'to', 'understand', 'human', 'language']

# %% [markdown]
# # Removing stopwords

# %%
stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word not in stop_words]
print("Tokens without Stopwords:", filtered_tokens)
# Out:
# Tokens without Stopwords: ['natural', 'language', 'processing', 'nlp', 'helps', 'computers', 'understand', 'human', 'language']

# %% [markdown]
# # Stemming

# %%
stemmer = PorterStemmer()
stemmed_tokens = [stemmer.stem(word) for word in filtered_tokens]
print("Stemmed Tokens:", stemmed_tokens)
# Out:
# Stemmed Tokens: ['natur', 'languag', 'process', 'nlp', 'help', 'comput', 'understand', 'human', 'languag']

# %% [markdown]
# # Lemmatization

# %%
lemmatizer = WordNetLemmatizer()
nltk.download('wordnet')
lemmatized_tokens = [lemmatizer.lemmatize(word) for word in filtered_tokens]
print("Lemmatized Tokens:", lemmatized_tokens)
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\Rawan
# [nltk_data]     Mohamed\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Lemmatized Tokens: ['natural', 'language', 'processing', 'nlp', 'help', 'computer', 'understand', 'human', 'language']

# %% [markdown]
# # Part of Speech Tagging

# %%
pos_tags = nltk.pos_tag(filtered_tokens)
print("POS Tags:", pos_tags)
# Out:
# POS Tags: [('natural', 'JJ'), ('language', 'NN'), ('processing', 'NN'), ('nlp', 'NN'), ('helps', 'VBZ'), ('computers', 'NNS'), ('understand', 'VBP'), ('human', 'JJ'), ('language', 'NN')]
